# %%
from pandas import read_csv
from sklearn.model_selection import KFold, cross_val_score #, LogisticRegression
from sklearn.linear_model import LogisticRegression
filename ='/Users/wangjiabin/ML_2020_summer/<ml with python practice>/chap_11_metric_for _algorithm_evaluation/housing.csv'
names =['RRIM','ZN','INDUS','CHAS','NOX','RM','AGE','DIS','RAD','TAX','RATATIO','B','LATAT','MEDV']
data = read_csv(filename, names =names,delim_whitespace =True)
#deliml_whitespace: If this option is set to True, nothing should be passed in for the delimiter parameter.
array =data.values
X = array[:,0:13]
Y = array[:,13]
n_splits =10
seed = 7
print(X.shape)
kfold =KFold(n_splits =n_splits,shuffle =True, random_state = seed)
model = LogisticRegression(solver='lbfgs',max_iter=999)
scoring = 'neg_mean_squared_error'
result = cross_val_score(model, X,Y, cv =kfold, scoring = scoring)
print('MSE: %.3f(%.3f)'% (result.mean(),result.std()))
# Out:
# (506, 13)
# MSE: nan(nan)
# /Users/wangjiabin/anaconda3/lib/python3.8/site-packages/sklearn/model_selection/_validation.py:548: FitFailedWarning: Estimator fit failed. The score on this train-test partition for these parameters will be set to nan. Details:
# Traceback (most recent call last):
#   File "/Users/wangjiabin/anaconda3/lib/python3.8/site-packages/sklearn/model_selection/_validation.py", line 531, in _fit_and_score
#     estimator.fit(X_train, y_train, **fit_params)
#   File "/Users/wangjiabin/anaconda3/lib/python3.8/site-packages/sklearn/linear_model/_logistic.py", line 1345, in fit
#     check_classification_targets(y)
#   File "/Users/wangjiabin/anaconda3/lib/python3.8/site-packages/sklearn/utils/multiclass.py", line 172, in check_classification_targets
#     raise ValueError("Unknown label type: %r" % y_type)
# ValueError: Unknown label type: 'continuous'
#
#   warnings.warn("Estimator fit failed. The score on this train-test"
# /Users/wangjiabin/anaconda3/lib/python3.8/site-packages/sklearn/model_selection/_validation.py:548: FitFailedWarning: Estimator fit failed. The score on this train-test partition for these parameters will be set to nan. Details:
# Traceback (most recent call last):
#   File "/Users/wangjiabin/anaconda3/lib/python3.8/site-packages/sklearn/model_selection/_validation.py", line 531, in _fit_and_score
#     estimator.fit(X_train, y_train, **fit_params)
#   File "/Users/wangjiabin/anaconda3/lib/python3.8/site-packages/sklearn/linear_model/_logistic.py", line 1345, in fit
#     check_classification_targets(y)
#   File "/Users/wangjiabin/anaconda3/lib/python3.8/site-packages/sklearn/utils/multiclass.py", line 172, in check_classification_targets
#     raise ValueError("Unknown label type: %r" % y_type)
# ValueError: Unknown label type: 'continuous'
#
#   warnings.warn("Estimator fit failed. The score on this train-test"
# /Users/wangjiabin/anaconda3/lib/python3.8/site-packages/sklearn/model_selection/_validation.py:548: FitFailedWarning: Estimator fit failed. The score on this train-test partition for these parameters will be set to nan. Details:
# Traceback (most recent call last):
#   File "/Users/wangjiabin/anaconda3/lib/python3.8/site-packages/sklearn/model_selection/_validation.py", line 531, in _fit_and_score
#     estimator.fit(X_train, y_train, **fit_params)
#   File "/Users/wangjiabin/anaconda3/lib/python3.8/site-packages/sklearn/linear_model/_logistic.py", line 1345, in fit
#     check_classification_targets(y)
#   File "/Users/wangjiabin/anaconda3/lib/python3.8/site-packages/sklearn/utils/multiclass.py", line 172, in check_classification_targets
#     raise ValueError("Unknown label type: %r" % y_type)
# ValueError: Unknown label type: 'continuous'
#
#   warnings.warn("Estimator fit failed. The score on this train-test"
# /Users/wangjiabin/anaconda3/lib/python3.8/site-packages/sklearn/model_selection/_validation.py:548: FitFailedWarning: Estimator fit failed. The score on this train-test partition for these parameters will be set to nan. Details:
# Traceback (most recent call last):
#   File "/Users/wangjiabin/anaconda3/lib/python3.8/site-packages/sklearn/model_selection/_validation.py", line 531, in _fit_and_score
#     estimator.fit(X_train, y_train, **fit_params)
#   File "/Users/wangjiabin/anaconda3/lib/python3.8/site-packages/sklearn/linear_model/_logistic.py", line 1345, in fit
#     check_classification_targets(y)
#   File "/Users/wangjiabin/anaconda3/lib/python3.8/site-packages/sklearn/utils/multiclass.py", line 172, in check_classification_targets
#     raise ValueError("Unknown label type: %r" % y_type)
# ValueError: Unknown label type: 'continuous'
#
#   warnings.warn("Estimator fit failed. The score on this train-test"
# /Users/wangjiabin/anaconda3/lib/python3.8/site-packages/sklearn/model_selection/_validation.py:548: FitFailedWarning: Estimator fit failed. The score on this train-test partition for these parameters will be set to nan. Details:
# Traceback (most recent call last):
#   File "/Users/wangjiabin/anaconda3/lib/python3.8/site-packages/sklearn/model_selection/_validation.py", line 531, in _fit_and_score
#     estimator.fit(X_train, y_train, **fit_params)
#   File "/Users/wangjiabin/anaconda3/lib/python3.8/site-packages/sklearn/linear_model/_logistic.py", line 1345, in fit
#     check_classification_targets(y)
#   File "/Users/wangjiabin/anaconda3/lib/python3.8/site-packages/sklearn/utils/multiclass.py", line 172, in check_classification_targets
#     raise ValueError("Unknown label type: %r" % y_type)
# ValueError: Unknown label type: 'continuous'
#
#   warnings.warn("Estimator fit failed. The score on this train-test"
# /Users/wangjiabin/anaconda3/lib/python3.8/site-packages/sklearn/model_selection/_validation.py:548: FitFailedWarning: Estimator fit failed. The score on this train-test partition for these parameters will be set to nan. Details:
# Traceback (most recent call last):
#   File "/Users/wangjiabin/anaconda3/lib/python3.8/site-packages/sklearn/model_selection/_validation.py", line 531, in _fit_and_score
#     estimator.fit(X_train, y_train, **fit_params)
#   File "/Users/wangjiabin/anaconda3/lib/python3.8/site-packages/sklearn/linear_model/_logistic.py", line 1345, in fit
#     check_classification_targets(y)
#   File "/Users/wangjiabin/anaconda3/lib/python3.8/site-packages/sklearn/utils/multiclass.py", line 172, in check_classification_targets
#     raise ValueError("Unknown label type: %r" % y_type)
# ValueError: Unknown label type: 'continuous'
#
#   warnings.warn("Estimator fit failed. The score on this train-test"
# /Users/wangjiabin/anaconda3/lib/python3.8/site-packages/sklearn/model_selection/_validation.py:548: FitFailedWarning: Estimator fit failed. The score on this train-test partition for these parameters will be set to nan. Details:
# Traceback (most recent call last):
#   File "/Users/wangjiabin/anaconda3/lib/python3.8/site-packages/sklearn/model_selection/_validation.py", line 531, in _fit_and_score
#     estimator.fit(X_train, y_train, **fit_params)
#   File "/Users/wangjiabin/anaconda3/lib/python3.8/site-packages/sklearn/linear_model/_logistic.py", line 1345, in fit
#     check_classification_targets(y)
#   File "/Users/wangjiabin/anaconda3/lib/python3.8/site-packages/sklearn/utils/multiclass.py", line 172, in check_classification_targets
#     raise ValueError("Unknown label type: %r" % y_type)
# ValueError: Unknown label type: 'continuous'
#
#   warnings.warn("Estimator fit failed. The score on this train-test"
# /Users/wangjiabin/anaconda3/lib/python3.8/site-packages/sklearn/model_selection/_validation.py:548: FitFailedWarning: Estimator fit failed. The score on this train-test partition for these parameters will be set to nan. Details:
# Traceback (most recent call last):
#   File "/Users/wangjiabin/anaconda3/lib/python3.8/site-packages/sklearn/model_selection/_validation.py", line 531, in _fit_and_score
#     estimator.fit(X_train, y_train, **fit_params)
#   File "/Users/wangjiabin/anaconda3/lib/python3.8/site-packages/sklearn/linear_model/_logistic.py", line 1345, in fit
#     check_classification_targets(y)
#   File "/Users/wangjiabin/anaconda3/lib/python3.8/site-packages/sklearn/utils/multiclass.py", line 172, in check_classification_targets
#     raise ValueError("Unknown label type: %r" % y_type)
# ValueError: Unknown label type: 'continuous'
#
#   warnings.warn("Estimator fit failed. The score on this train-test"
# /Users/wangjiabin/anaconda3/lib/python3.8/site-packages/sklearn/model_selection/_validation.py:548: FitFailedWarning: Estimator fit failed. The score on this train-test partition for these parameters will be set to nan. Details:
# Traceback (most recent call last):
#   File "/Users/wangjiabin/anaconda3/lib/python3.8/site-packages/sklearn/model_selection/_validation.py", line 531, in _fit_and_score
#     estimator.fit(X_train, y_train, **fit_params)
#   File "/Users/wangjiabin/anaconda3/lib/python3.8/site-packages/sklearn/linear_model/_logistic.py", line 1345, in fit
#     check_classification_targets(y)
#   File "/Users/wangjiabin/anaconda3/lib/python3.8/site-packages/sklearn/utils/multiclass.py", line 172, in check_classification_targets
#     raise ValueError("Unknown label type: %r" % y_type)
# ValueError: Unknown label type: 'continuous'
#
#   warnings.warn("Estimator fit failed. The score on this train-test"
# /Users/wangjiabin/anaconda3/lib/python3.8/site-packages/sklearn/model_selection/_validation.py:548: FitFailedWarning: Estimator fit failed. The score on this train-test partition for these parameters will be set to nan. Details:
# Traceback (most recent call last):
#   File "/Users/wangjiabin/anaconda3/lib/python3.8/site-packages/sklearn/model_selection/_validation.py", line 531, in _fit_and_score
#     estimator.fit(X_train, y_train, **fit_params)
#   File "/Users/wangjiabin/anaconda3/lib/python3.8/site-packages/sklearn/linear_model/_logistic.py", line 1345, in fit
#     check_classification_targets(y)
#   File "/Users/wangjiabin/anaconda3/lib/python3.8/site-packages/sklearn/utils/multiclass.py", line 172, in check_classification_targets
#     raise ValueError("Unknown label type: %r" % y_type)
# ValueError: Unknown label type: 'continuous'
#
#   warnings.warn("Estimator fit failed. The score on this train-test"
