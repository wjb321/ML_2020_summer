# %%
import pandas as pd
#from pandas import read_csv
import matplotlib.pyplot as plt
filename ='/Users/wangjiabin/ML_2020_summer/<ml with python practice>/cha_7_data_visibility/pima_data.csv'
columns =['Pregnancies', 'Glucose','BloodPressure','SkinThickness','Insulin','BMI','DiabetesPedigreeFunction','Age','Outcome']
dataset =pd.read_csv(filename)#, names=names, sep=','
#print(dataset.head(10))
#print(dataset.describe())
#print(data.dtype)

# %% [markdown]
# 此处问题是，hist需要参数column，由于csv文件的读取后有不同column的值，此时通过列表将column的值保存，在用hist的时候，参数就采用column=columns。参考文件给的dataset.hist()是不对的。需要参数。
# **1)**可视化参考：https://www.cnblogs.com/kylinlin/p/5234223.html
# **2)**同时，当CSV文件column中没有具体的features时候，如何添加features呢？https://stackoverflow.com/questions/31645466/give-column-name-when-read-csv-file-pandas

# %% [markdown]
# # 1)直方图，histgram()

# %%
dataset.hist(column=columns,layout=(3,3),grid = False, figsize = (20,10))
plt.show()

# %% [markdown]
# # 2)密度图

# %%
import matplotlib.pyplot as plt
dataset.plot(kind = 'density', subplots =True, layout =(3,3), sharex=False, figsize = (20,10))
plt.show()

# %% [markdown]
# # 3)箱线图

# %%
dataset.plot(kind = 'box', subplots =True, layout =(3,3), sharex=False, figsize = (20,10))
plt.show()

# %% [markdown]
# # 4）相关矩阵图

# %%
import numpy as np
correlations = dataset.corr()
fig = plt.figure()
ax = fig.add_subplot(111)
cax =ax.matshow(correlations, vmin =-1, vmax =1)
fig.colorbar(cax)
ticks =np.arange(0,9,1)
ax.set_xticks(ticks)
ax.set_yticks(ticks)
ax.set_xticklabels(columns,rotation = 90)
ax.set_yticklabels(columns)
plt.show()

# %% [markdown]
# # 5）散点图

# %% [markdown]
# for 循环部分牵扯横纵坐标旋转，解决label重叠问题。

# %%
from pandas.plotting import scatter_matrix
axs = scatter_matrix(dataset, alpha =0.2)#,diagonal='kde'
#plt.tight_layout()
n = len(dataset.columns)
for x in range(n):
    for y in range(n):
        # to get the axis of subplots
        ax = axs[x, y]
        # to make x axis name vertical  
        ax.xaxis.label.set_rotation(90)
        # to make y axis name horizontal 
        ax.yaxis.label.set_rotation(0)
        # to make sure y axis names are outside the plot area
        ax.yaxis.labelpad = 50

#plt.show()
